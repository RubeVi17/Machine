# %%
# !conda activate stock

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='DRUC9YCOWVAT2QVE', output_format='pandas')

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=16,8
plt.style.use('seaborn-darkgrid')
import numpy as np

# %%
SPY, meta_data = ts.get_daily('SPY', outputsize='full')
SPY.head()
# Out:
#               open    high       low   close      volume
# 2020-05-11  290.34  294.00  289.8800  292.50  68529208.0
# 2020-05-08  291.09  292.95  289.8600  292.44  76446082.0
# 2020-05-07  287.75  289.78  287.1300  287.68  74788296.0
# 2020-05-06  288.04  288.46  283.7800  284.25  72980387.0
# 2020-05-05  286.64  289.25  283.7134  286.19  79199214.0

# %%
SPY['close'].plot()
plt.title('Test de datos con alpha vantage')
plt.legend()

# %%
# !conda deactivate
